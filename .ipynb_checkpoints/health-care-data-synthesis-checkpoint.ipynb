# %%
import pandas as pd

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv')
df3 = pd.read_csv('data3.csv')

# %%
df1
# Out:
#        2021-10-24 00:33:00  19  20850235  F      PLAQUETAS SANGUE   316,00
# 0      2021-10-24 00:33:00  70  16084789  M      PLAQUETAS SANGUE   239,00
# 1      2021-10-24 00:33:00  62  25926519  F      PLAQUETAS SANGUE   166,00
# 2      2021-10-24 00:33:00  49  20209887  M      PLAQUETAS SANGUE   201,00
# 3      2021-10-24 00:33:00  50  25722538  M      PLAQUETAS SANGUE   319,00
# 4      2021-10-24 00:33:00  19  20850235  F  NEUTRÓFILOS ABSOLUTO   9,9006
# ...                    ...  ..       ... ..                   ...      ...
# 69438  2021-12-10 05:44:00  52  14708160  F      PLAQUETAS SANGUE   172,00
# 69439  2021-12-10 05:44:00  52  14708160  F  NEUTRÓFILOS ABSOLUTO  10,4661
# 69440  2021-12-10 05:44:00  52  14708160  F   LINFÓCITOS ABSOLUTO   0,3609
# 69441  2021-12-10 05:44:00  52  14708160  F         NEUTRÓFILOS %     87,0
# 69442  2021-12-10 05:44:00  52  14708160  F          LINFÓCITOS %      3,0
#
# [69443 rows x 6 columns]

# %%
df1.columns = df1.columns.str.lower().str.replace(' ', '_')
df1
# Out:
#        2021-10-24_00:33:00  19  20850235  f      plaquetas_sangue   316,00
# 0      2021-10-24 00:33:00  70  16084789  M      PLAQUETAS SANGUE   239,00
# 1      2021-10-24 00:33:00  62  25926519  F      PLAQUETAS SANGUE   166,00
# 2      2021-10-24 00:33:00  49  20209887  M      PLAQUETAS SANGUE   201,00
# 3      2021-10-24 00:33:00  50  25722538  M      PLAQUETAS SANGUE   319,00
# 4      2021-10-24 00:33:00  19  20850235  F  NEUTRÓFILOS ABSOLUTO   9,9006
# ...                    ...  ..       ... ..                   ...      ...
# 69438  2021-12-10 05:44:00  52  14708160  F      PLAQUETAS SANGUE   172,00
# 69439  2021-12-10 05:44:00  52  14708160  F  NEUTRÓFILOS ABSOLUTO  10,4661
# 69440  2021-12-10 05:44:00  52  14708160  F   LINFÓCITOS ABSOLUTO   0,3609
# 69441  2021-12-10 05:44:00  52  14708160  F         NEUTRÓFILOS %     87,0
# 69442  2021-12-10 05:44:00  52  14708160  F          LINFÓCITOS %      3,0
#
# [69443 rows x 6 columns]

# %%
df1.rename(columns={'2021-10-24_00:33:00':'date_time'}, inplace=True)

# %%
df1
# Out:
#                  date_time  19  20850235  f      plaquetas_sangue   316,00
# 0      2021-10-24 00:33:00  70  16084789  M      PLAQUETAS SANGUE   239,00
# 1      2021-10-24 00:33:00  62  25926519  F      PLAQUETAS SANGUE   166,00
# 2      2021-10-24 00:33:00  49  20209887  M      PLAQUETAS SANGUE   201,00
# 3      2021-10-24 00:33:00  50  25722538  M      PLAQUETAS SANGUE   319,00
# 4      2021-10-24 00:33:00  19  20850235  F  NEUTRÓFILOS ABSOLUTO   9,9006
# ...                    ...  ..       ... ..                   ...      ...
# 69438  2021-12-10 05:44:00  52  14708160  F      PLAQUETAS SANGUE   172,00
# 69439  2021-12-10 05:44:00  52  14708160  F  NEUTRÓFILOS ABSOLUTO  10,4661
# 69440  2021-12-10 05:44:00  52  14708160  F   LINFÓCITOS ABSOLUTO   0,3609
# 69441  2021-12-10 05:44:00  52  14708160  F         NEUTRÓFILOS %     87,0
# 69442  2021-12-10 05:44:00  52  14708160  F          LINFÓCITOS %      3,0
#
# [69443 rows x 6 columns]

# %%
df1.rename(columns={'19':'age'}, inplace=True)

# %%
df1
# Out:
#                  date_time  age  20850235  f      plaquetas_sangue   316,00
# 0      2021-10-24 00:33:00   70  16084789  M      PLAQUETAS SANGUE   239,00
# 1      2021-10-24 00:33:00   62  25926519  F      PLAQUETAS SANGUE   166,00
# 2      2021-10-24 00:33:00   49  20209887  M      PLAQUETAS SANGUE   201,00
# 3      2021-10-24 00:33:00   50  25722538  M      PLAQUETAS SANGUE   319,00
# 4      2021-10-24 00:33:00   19  20850235  F  NEUTRÓFILOS ABSOLUTO   9,9006
# ...                    ...  ...       ... ..                   ...      ...
# 69438  2021-12-10 05:44:00   52  14708160  F      PLAQUETAS SANGUE   172,00
# 69439  2021-12-10 05:44:00   52  14708160  F  NEUTRÓFILOS ABSOLUTO  10,4661
# 69440  2021-12-10 05:44:00   52  14708160  F   LINFÓCITOS ABSOLUTO   0,3609
# 69441  2021-12-10 05:44:00   52  14708160  F         NEUTRÓFILOS %     87,0
# 69442  2021-12-10 05:44:00   52  14708160  F          LINFÓCITOS %      3,0
#
# [69443 rows x 6 columns]

# %%
df1.rename(columns={'20850235': 'patient_id', 'f': 'gender'}, inplace=True)

# %%
df1
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 0      2021-10-24 00:33:00   70    16084789      M      PLAQUETAS SANGUE
# 1      2021-10-24 00:33:00   62    25926519      F      PLAQUETAS SANGUE
# 2      2021-10-24 00:33:00   49    20209887      M      PLAQUETAS SANGUE
# 3      2021-10-24 00:33:00   50    25722538      M      PLAQUETAS SANGUE
# 4      2021-10-24 00:33:00   19    20850235      F  NEUTRÓFILOS ABSOLUTO
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10 05:44:00   52    14708160      F      PLAQUETAS SANGUE
# 69439  2021-12-10 05:44:00   52    14708160      F  NEUTRÓFILOS ABSOLUTO
# 69440  2021-12-10 05:44:00   52    14708160      F   LINFÓCITOS ABSOLUTO
# 69441  2021-12-10 05:44:00   52    14708160      F         NEUTRÓFILOS %
# 69442  2021-12-10 05:44:00   52    14708160      F          LINFÓCITOS %
#
#         316,00
# 0       239,00
# 1       166,00
# 2       201,00
# 3       319,00
# 4       9,9006
# ...        ...
# 69438   172,00
# 69439  10,4661
# 69440   0,3609
# 69441     87,0
# 69442      3,0
#
# [69443 rows x 6 columns]

# %%
categorical_columns = list(df1.dtypes[df1.dtypes == 'str'].index)

for categorical_column in categorical_columns:
    df1[categorical_column] = df1[categorical_column].str.lower().str.replace(' ', '_')

# %%
df1
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 0      2021-10-24_00:33:00   70    16084789      m      plaquetas_sangue
# 1      2021-10-24_00:33:00   62    25926519      f      plaquetas_sangue
# 2      2021-10-24_00:33:00   49    20209887      m      plaquetas_sangue
# 3      2021-10-24_00:33:00   50    25722538      m      plaquetas_sangue
# 4      2021-10-24_00:33:00   19    20850235      f  neutrófilos_absoluto
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10_05:44:00   52    14708160      f      plaquetas_sangue
# 69439  2021-12-10_05:44:00   52    14708160      f  neutrófilos_absoluto
# 69440  2021-12-10_05:44:00   52    14708160      f   linfócitos_absoluto
# 69441  2021-12-10_05:44:00   52    14708160      f         neutrófilos_%
# 69442  2021-12-10_05:44:00   52    14708160      f          linfócitos_%
#
#         316,00
# 0       239,00
# 1       166,00
# 2       201,00
# 3       319,00
# 4       9,9006
# ...        ...
# 69438   172,00
# 69439  10,4661
# 69440   0,3609
# 69441     87,0
# 69442      3,0
#
# [69443 rows x 6 columns]

# %%
df1.rename(columns={'316,00': 'quantity'}, inplace=True)

# %%
df1
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 0      2021-10-24_00:33:00   70    16084789      m      plaquetas_sangue
# 1      2021-10-24_00:33:00   62    25926519      f      plaquetas_sangue
# 2      2021-10-24_00:33:00   49    20209887      m      plaquetas_sangue
# 3      2021-10-24_00:33:00   50    25722538      m      plaquetas_sangue
# 4      2021-10-24_00:33:00   19    20850235      f  neutrófilos_absoluto
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10_05:44:00   52    14708160      f      plaquetas_sangue
# 69439  2021-12-10_05:44:00   52    14708160      f  neutrófilos_absoluto
# 69440  2021-12-10_05:44:00   52    14708160      f   linfócitos_absoluto
# 69441  2021-12-10_05:44:00   52    14708160      f         neutrófilos_%
# 69442  2021-12-10_05:44:00   52    14708160      f          linfócitos_%
#
#       quantity
# 0       239,00
# 1       166,00
# 2       201,00
# 3       319,00
# 4       9,9006
# ...        ...
# 69438   172,00
# 69439  10,4661
# 69440   0,3609
# 69441     87,0
# 69442      3,0
#
# [69443 rows x 6 columns]

# %%
df2
# Out:
#         2019-04-07 13:36:00  38  22536285  M      PLAQUETAS SANGUE  282,00
# 0       2019-04-07 13:36:00  38  22536285  M  NEUTRÓFILOS ABSOLUTO  5,8476
# 1       2019-04-07 13:36:00  38  22536285  M   LINFÓCITOS ABSOLUTO  3,1896
# 2       2019-04-07 13:36:00  38  22536285  M         NEUTRÓFILOS %    44,0
# 3       2019-04-07 13:36:00  38  22536285  M          LINFÓCITOS %    24,0
# 4       2019-10-12 12:53:00   7  25368842  M      PLAQUETAS SANGUE  268,00
# ...                     ...  ..       ... ..                   ...     ...
# 152918  2020-11-19 10:09:00  43  24249245  M      PLAQUETAS SANGUE  234,00
# 152919  2020-11-19 10:09:00  43  24249245  M  NEUTRÓFILOS ABSOLUTO  3,8994
# 152920  2020-11-19 10:09:00  43  24249245  M   LINFÓCITOS ABSOLUTO  1,8293
# 152921  2020-11-19 10:09:00  43  24249245  M         NEUTRÓFILOS %    59,9
# 152922  2020-11-19 10:09:00  43  24249245  M          LINFÓCITOS %    28,1
#
# [152923 rows x 6 columns]

# %%
df2.rename(columns={'2019-04-07 13:36:00': 'date_time', '38': 'age', '22536285': 'patient_id', 'M': 'gender', '282,00': 'quantity'}, 
          inplace=True)

# %%
df2
# Out:
#                   date_time  age  patient_id gender      PLAQUETAS SANGUE  \
# 0       2019-04-07 13:36:00   38    22536285      M  NEUTRÓFILOS ABSOLUTO
# 1       2019-04-07 13:36:00   38    22536285      M   LINFÓCITOS ABSOLUTO
# 2       2019-04-07 13:36:00   38    22536285      M         NEUTRÓFILOS %
# 3       2019-04-07 13:36:00   38    22536285      M          LINFÓCITOS %
# 4       2019-10-12 12:53:00    7    25368842      M      PLAQUETAS SANGUE
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19 10:09:00   43    24249245      M      PLAQUETAS SANGUE
# 152919  2020-11-19 10:09:00   43    24249245      M  NEUTRÓFILOS ABSOLUTO
# 152920  2020-11-19 10:09:00   43    24249245      M   LINFÓCITOS ABSOLUTO
# 152921  2020-11-19 10:09:00   43    24249245      M         NEUTRÓFILOS %
# 152922  2020-11-19 10:09:00   43    24249245      M          LINFÓCITOS %
#
#        quantity
# 0        5,8476
# 1        3,1896
# 2          44,0
# 3          24,0
# 4        268,00
# ...         ...
# 152918   234,00
# 152919   3,8994
# 152920   1,8293
# 152921     59,9
# 152922     28,1
#
# [152923 rows x 6 columns]

# %%
categorical_columns_df2 = list(df2.dtypes[df2.dtypes == 'str'].index)

for categorical_column in categorical_columns_df2:
    df2[categorical_column] = df2[categorical_column].str.lower().str.replace(' ', '_')

# %%
df2
# Out:
#                   date_time  age  patient_id gender      PLAQUETAS SANGUE  \
# 0       2019-04-07_13:36:00   38    22536285      m  neutrófilos_absoluto
# 1       2019-04-07_13:36:00   38    22536285      m   linfócitos_absoluto
# 2       2019-04-07_13:36:00   38    22536285      m         neutrófilos_%
# 3       2019-04-07_13:36:00   38    22536285      m          linfócitos_%
# 4       2019-10-12_12:53:00    7    25368842      m      plaquetas_sangue
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19_10:09:00   43    24249245      m      plaquetas_sangue
# 152919  2020-11-19_10:09:00   43    24249245      m  neutrófilos_absoluto
# 152920  2020-11-19_10:09:00   43    24249245      m   linfócitos_absoluto
# 152921  2020-11-19_10:09:00   43    24249245      m         neutrófilos_%
# 152922  2020-11-19_10:09:00   43    24249245      m          linfócitos_%
#
#        quantity
# 0        5,8476
# 1        3,1896
# 2          44,0
# 3          24,0
# 4        268,00
# ...         ...
# 152918   234,00
# 152919   3,8994
# 152920   1,8293
# 152921     59,9
# 152922     28,1
#
# [152923 rows x 6 columns]

# %%
df2.columns = df2.columns.str.lower().str.replace(' ', '_')

# %%
df2
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2019-04-07_13:36:00   38    22536285      m  neutrófilos_absoluto
# 1       2019-04-07_13:36:00   38    22536285      m   linfócitos_absoluto
# 2       2019-04-07_13:36:00   38    22536285      m         neutrófilos_%
# 3       2019-04-07_13:36:00   38    22536285      m          linfócitos_%
# 4       2019-10-12_12:53:00    7    25368842      m      plaquetas_sangue
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19_10:09:00   43    24249245      m      plaquetas_sangue
# 152919  2020-11-19_10:09:00   43    24249245      m  neutrófilos_absoluto
# 152920  2020-11-19_10:09:00   43    24249245      m   linfócitos_absoluto
# 152921  2020-11-19_10:09:00   43    24249245      m         neutrófilos_%
# 152922  2020-11-19_10:09:00   43    24249245      m          linfócitos_%
#
#        quantity
# 0        5,8476
# 1        3,1896
# 2          44,0
# 3          24,0
# 4        268,00
# ...         ...
# 152918   234,00
# 152919   3,8994
# 152920   1,8293
# 152921     59,9
# 152922     28,1
#
# [152923 rows x 6 columns]

# %%
df3
# Out:
#         2021-07-24 00:18:00  73  25834403  M      PLAQUETAS SANGUE  403,00
# 0       2021-07-24 00:18:00  73  25834403  M  NEUTRÓFILOS ABSOLUTO  2,9153
# 1       2021-07-24 00:18:00  73  25834403  M   LINFÓCITOS ABSOLUTO  1,8109
# 2       2021-07-24 00:18:00  73  25834403  M         NEUTRÓFILOS %    29,3
# 3       2021-07-24 00:18:00  73  25834403  M          LINFÓCITOS %    18,2
# 4       2021-07-24 00:19:00  17  25848842  F      PLAQUETAS SANGUE  321,00
# ...                     ...  ..       ... ..                   ...     ...
# 134477  2021-12-03 09:31:00  25  24766171  M      PLAQUETAS SANGUE   58,00
# 134478  2021-12-03 09:31:00  25  24766171  M  NEUTRÓFILOS ABSOLUTO  1,2600
# 134479  2021-12-03 09:31:00  25  24766171  M   LINFÓCITOS ABSOLUTO  1,3104
# 134480  2021-12-03 09:31:00  25  24766171  M         NEUTRÓFILOS %    45,0
# 134481  2021-12-03 09:31:00  25  24766171  M          LINFÓCITOS %    46,8
#
# [134482 rows x 6 columns]

# %%
df3.columns = df3.columns.str.lower().str.replace(' ', '_')

# %%
df3
# Out:
#         2021-07-24_00:18:00  73  25834403  m      plaquetas_sangue  403,00
# 0       2021-07-24 00:18:00  73  25834403  M  NEUTRÓFILOS ABSOLUTO  2,9153
# 1       2021-07-24 00:18:00  73  25834403  M   LINFÓCITOS ABSOLUTO  1,8109
# 2       2021-07-24 00:18:00  73  25834403  M         NEUTRÓFILOS %    29,3
# 3       2021-07-24 00:18:00  73  25834403  M          LINFÓCITOS %    18,2
# 4       2021-07-24 00:19:00  17  25848842  F      PLAQUETAS SANGUE  321,00
# ...                     ...  ..       ... ..                   ...     ...
# 134477  2021-12-03 09:31:00  25  24766171  M      PLAQUETAS SANGUE   58,00
# 134478  2021-12-03 09:31:00  25  24766171  M  NEUTRÓFILOS ABSOLUTO  1,2600
# 134479  2021-12-03 09:31:00  25  24766171  M   LINFÓCITOS ABSOLUTO  1,3104
# 134480  2021-12-03 09:31:00  25  24766171  M         NEUTRÓFILOS %    45,0
# 134481  2021-12-03 09:31:00  25  24766171  M          LINFÓCITOS %    46,8
#
# [134482 rows x 6 columns]

# %%
df3.rename(columns={'2021-07-24_00:18:00': 'date_time', '73': 'age', '25834403': 'patient_id', 'm': 'gender', '403,00': 'quantity'}, inplace=True)

# %%
df3
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2021-07-24 00:18:00   73    25834403      M  NEUTRÓFILOS ABSOLUTO
# 1       2021-07-24 00:18:00   73    25834403      M   LINFÓCITOS ABSOLUTO
# 2       2021-07-24 00:18:00   73    25834403      M         NEUTRÓFILOS %
# 3       2021-07-24 00:18:00   73    25834403      M          LINFÓCITOS %
# 4       2021-07-24 00:19:00   17    25848842      F      PLAQUETAS SANGUE
# ...                     ...  ...         ...    ...                   ...
# 134477  2021-12-03 09:31:00   25    24766171      M      PLAQUETAS SANGUE
# 134478  2021-12-03 09:31:00   25    24766171      M  NEUTRÓFILOS ABSOLUTO
# 134479  2021-12-03 09:31:00   25    24766171      M   LINFÓCITOS ABSOLUTO
# 134480  2021-12-03 09:31:00   25    24766171      M         NEUTRÓFILOS %
# 134481  2021-12-03 09:31:00   25    24766171      M          LINFÓCITOS %
#
#        quantity
# 0        2,9153
# 1        1,8109
# 2          29,3
# 3          18,2
# 4        321,00
# ...         ...
# 134477    58,00
# 134478   1,2600
# 134479   1,3104
# 134480     45,0
# 134481     46,8
#
# [134482 rows x 6 columns]

# %%
categorical_columns_df3 = list(df3.dtypes[df3.dtypes == 'str'].index)

for categorical_column in categorical_columns_df3:
    df3[categorical_column] = df3[categorical_column].str.lower().replace(' ', '_')

# %%
df3
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2021-07-24 00:18:00   73    25834403      m  neutrófilos absoluto
# 1       2021-07-24 00:18:00   73    25834403      m   linfócitos absoluto
# 2       2021-07-24 00:18:00   73    25834403      m         neutrófilos %
# 3       2021-07-24 00:18:00   73    25834403      m          linfócitos %
# 4       2021-07-24 00:19:00   17    25848842      f      plaquetas sangue
# ...                     ...  ...         ...    ...                   ...
# 134477  2021-12-03 09:31:00   25    24766171      m      plaquetas sangue
# 134478  2021-12-03 09:31:00   25    24766171      m  neutrófilos absoluto
# 134479  2021-12-03 09:31:00   25    24766171      m   linfócitos absoluto
# 134480  2021-12-03 09:31:00   25    24766171      m         neutrófilos %
# 134481  2021-12-03 09:31:00   25    24766171      m          linfócitos %
#
#        quantity
# 0        2,9153
# 1        1,8109
# 2          29,3
# 3          18,2
# 4        321,00
# ...         ...
# 134477    58,00
# 134478   1,2600
# 134479   1,3104
# 134480     45,0
# 134481     46,8
#
# [134482 rows x 6 columns]

# %%
df1[48:]
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 48     2021-10-24_03:02:00   40    20074602      f          linfócitos_%
# 49     2021-10-24_05:31:00   54    25595648      f     leucócitos_totais
# 50     2021-10-24_05:31:00   61    25149430      m     leucócitos_totais
# 51     2021-10-24_05:31:00   59    12805068      m     leucócitos_totais
# 52     2021-10-24_05:31:00   58    24932063      f     leucócitos_totais
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10_05:44:00   52    14708160      f      plaquetas_sangue
# 69439  2021-12-10_05:44:00   52    14708160      f  neutrófilos_absoluto
# 69440  2021-12-10_05:44:00   52    14708160      f   linfócitos_absoluto
# 69441  2021-12-10_05:44:00   52    14708160      f         neutrófilos_%
# 69442  2021-12-10_05:44:00   52    14708160      f          linfócitos_%
#
#       quantity
# 48        36,7
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# ...        ...
# 69438   172,00
# 69439  10,4661
# 69440   0,3609
# 69441     87,0
# 69442      3,0
#
# [69395 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df1['quantity'] = df1['quantity'].astype(str)
# df1['quantity'] = df1['quantity'].str.replace(',', '.')
# df1['quantity'] = pd.to_numeric(df1['quantity'], errors='coerce')

# %%
df1
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 0      2021-10-24_00:33:00   70    16084789      m      plaquetas_sangue
# 1      2021-10-24_00:33:00   62    25926519      f      plaquetas_sangue
# 2      2021-10-24_00:33:00   49    20209887      m      plaquetas_sangue
# 3      2021-10-24_00:33:00   50    25722538      m      plaquetas_sangue
# 4      2021-10-24_00:33:00   19    20850235      f  neutrófilos_absoluto
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10_05:44:00   52    14708160      f      plaquetas_sangue
# 69439  2021-12-10_05:44:00   52    14708160      f  neutrófilos_absoluto
# 69440  2021-12-10_05:44:00   52    14708160      f   linfócitos_absoluto
# 69441  2021-12-10_05:44:00   52    14708160      f         neutrófilos_%
# 69442  2021-12-10_05:44:00   52    14708160      f          linfócitos_%
#
#       quantity
# 0       239,00
# 1       166,00
# 2       201,00
# 3       319,00
# 4       9,9006
# ...        ...
# 69438   172,00
# 69439  10,4661
# 69440   0,3609
# 69441     87,0
# 69442      3,0
#
# [69443 rows x 6 columns]

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 69443 entries, 0 to 69442
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_time         69443 non-null  str
#  1   age               69443 non-null  int64
#  2   patient_id        69443 non-null  int64
#  3   gender            69443 non-null  str
#  4   plaquetas_sangue  69443 non-null  str
#  5   quantity          62162 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 3.2 MB

# %%
df1.isnull().sum()
# Out:
# date_time              0
# age                    0
# patient_id             0
# gender                 0
# plaquetas_sangue       0
# quantity            7281
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# date_time              0
# age                    0
# patient_id             0
# gender                 0
# plaquetas_sangue       0
# quantity            8638
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# date_time               0
# age                     0
# patient_id              0
# gender                  0
# plaquetas_sangue        0
# quantity            11889
# dtype: int64

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                  date_time  age  patient_id gender   plaquetas_sangue quantity
# 49     2021-10-24_05:31:00   54    25595648      f  leucócitos_totais      NaN
# 50     2021-10-24_05:31:00   61    25149430      m  leucócitos_totais      NaN
# 51     2021-10-24_05:31:00   59    12805068      m  leucócitos_totais      NaN
# 52     2021-10-24_05:31:00   58    24932063      f  leucócitos_totais      NaN
# 53     2021-10-24_05:31:00   63    24909035      f  leucócitos_totais      NaN
# ...                    ...  ...         ...    ...                ...      ...
# 67433  2021-12-09_07:30:00   54    12284312      m     observação_wbc      NaN
# 67434  2021-12-09_07:30:00   61    25843342      f     observação_rbc      NaN
# 67435  2021-12-09_07:30:00   54    12284312      m     observação_rbc      NaN
# 67436  2021-12-09_07:30:00   61    25843342      f     observação_plt      NaN
# 67437  2021-12-09_07:30:00   54    12284312      m     observação_plt      NaN
#
# [7281 rows x 6 columns]

# %%
(df1.isnull().sum() / len(df1)) * 100
# Out:
# date_time            0.000000
# age                  0.000000
# patient_id           0.000000
# gender               0.000000
# plaquetas_sangue     0.000000
# quantity            10.484858
# dtype: float64

# %%
(df2.isnull().sum() / len(df2)) * 100
# Out:
# date_time           0.000000
# age                 0.000000
# patient_id          0.000000
# gender              0.000000
# plaquetas_sangue    0.000000
# quantity            5.648594
# dtype: float64

# %%
(df3.isnull().sum() / len(df3)) * 100
# Out:
# date_time           0.000000
# age                 0.000000
# patient_id          0.000000
# gender              0.000000
# plaquetas_sangue    0.000000
# quantity            8.840588
# dtype: float64

# %%
sns.heatmap(df1.isnull(), cbar=False)
plt.show()

# %%
sns.heatmap(df2.isnull(), cbar=False)
plt.show()

# %%
sns.heatmap(df3.isnull(), cbar=False)
plt.show()

# %%
df1[df1 == "__"].count()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            5
# dtype: int64

# %%
df2[df2 == "__"].count()
# Out:
# date_time            0
# age                  0
# patient_id           0
# gender               0
# plaquetas_sangue     0
# quantity            21
# dtype: int64

# %%
df3[df3 == "__"].count()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df1[df1 == "NaN"].count()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df2[df2 == "NaN"].count()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df3[df3 == "NaN"].count()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
import numpy as np

df1 = df1.replace(["__", "NA", "N/A", "?", "null", "", "_____","_______________","_____________", "________________", "_____________________", "____________________", "______________________", "___________________________", "_", "  ", "      ", "   ", "    ", "           ", "            ", "          ", "       ", "         ", "        ", "     ", "                       "], np.nan)
df2 = df2.replace(["__", "NA", "N/A", "?", "null", "", "_____","_______________","_____________", "________________", "_____________________", "____________________", "______________________", "___________________________","_", "  ", "      ", "   ", "    ", "           ", "            ", "          ", "       ", "         ", "        ", "     ", "                       "], np.nan)
df3 = df3.replace(["__", "NA", "N/A", "?", "null", "", "_____","_______________","_____________", "________________", "_____________________", "____________________", "______________________", "___________________________","_", "  ", "      ", "   ", "    ", "           ", "            ", "          ", "       ", "         ", "        ", "     ", "                       "], np.nan)

# %%
df1['quantity'].isnull().sum()
# Out:
# np.int64(7336)

# %%
df2['quantity'].isnull().sum()
# Out:
# np.int64(10156)

# %%
df3['quantity'].isnull().sum()
# Out:
# np.int64(12133)

# %%
# df1['quantity'] = pd.to_numeric(df1['quantity'], errors='coerce')
# df2['quantity'] = pd.to_numeric(df2['quantity'], errors='coerce')
# df3['quantity'] = pd.to_numeric(df3['quantity'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 69443 entries, 0 to 69442
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_time         69443 non-null  str
#  1   age               69443 non-null  int64
#  2   patient_id        69443 non-null  int64
#  3   gender            69443 non-null  str
#  4   plaquetas_sangue  69443 non-null  str
#  5   quantity          62107 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 3.2 MB

# %%
df2['quantity'] = (
    df2['quantity']
    .astype(str)
    .str.replace(',', '.', regex=False)
)

# %%
df2
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2019-04-07_13:36:00   38    22536285      m  neutrófilos_absoluto
# 1       2019-04-07_13:36:00   38    22536285      m   linfócitos_absoluto
# 2       2019-04-07_13:36:00   38    22536285      m         neutrófilos_%
# 3       2019-04-07_13:36:00   38    22536285      m          linfócitos_%
# 4       2019-10-12_12:53:00    7    25368842      m      plaquetas_sangue
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19_10:09:00   43    24249245      m      plaquetas_sangue
# 152919  2020-11-19_10:09:00   43    24249245      m  neutrófilos_absoluto
# 152920  2020-11-19_10:09:00   43    24249245      m   linfócitos_absoluto
# 152921  2020-11-19_10:09:00   43    24249245      m         neutrófilos_%
# 152922  2020-11-19_10:09:00   43    24249245      m          linfócitos_%
#
#        quantity
# 0        5.8476
# 1        3.1896
# 2          44.0
# 3          24.0
# 4        268.00
# ...         ...
# 152918   234.00
# 152919   3.8994
# 152920   1.8293
# 152921     59.9
# 152922     28.1
#
# [152923 rows x 6 columns]

# %%
df2['quantity'] = pd.to_numeric(df2['quantity'])

# %%
df2
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2019-04-07_13:36:00   38    22536285      m  neutrófilos_absoluto
# 1       2019-04-07_13:36:00   38    22536285      m   linfócitos_absoluto
# 2       2019-04-07_13:36:00   38    22536285      m         neutrófilos_%
# 3       2019-04-07_13:36:00   38    22536285      m          linfócitos_%
# 4       2019-10-12_12:53:00    7    25368842      m      plaquetas_sangue
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19_10:09:00   43    24249245      m      plaquetas_sangue
# 152919  2020-11-19_10:09:00   43    24249245      m  neutrófilos_absoluto
# 152920  2020-11-19_10:09:00   43    24249245      m   linfócitos_absoluto
# 152921  2020-11-19_10:09:00   43    24249245      m         neutrófilos_%
# 152922  2020-11-19_10:09:00   43    24249245      m          linfócitos_%
#
#         quantity
# 0         5.8476
# 1         3.1896
# 2        44.0000
# 3        24.0000
# 4       268.0000
# ...          ...
# 152918  234.0000
# 152919    3.8994
# 152920    1.8293
# 152921   59.9000
# 152922   28.1000
#
# [152923 rows x 6 columns]

# %%
df3['quantity'] = (
    df3['quantity']
    .astype(str)
    .str.replace(',', '.', regex=False)
)

# %%
df3['quantity'] = pd.to_numeric(df3['quantity'])

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134482 entries, 0 to 134481
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date_time         134482 non-null  str
#  1   age               134482 non-null  int64
#  2   patient_id        134482 non-null  int64
#  3   gender            134482 non-null  str
#  4   plaquetas_sangue  134482 non-null  str
#  5   quantity          122349 non-null  float64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 6.2 MB

# %%
df3
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2021-07-24 00:18:00   73    25834403      m  neutrófilos absoluto
# 1       2021-07-24 00:18:00   73    25834403      m   linfócitos absoluto
# 2       2021-07-24 00:18:00   73    25834403      m         neutrófilos %
# 3       2021-07-24 00:18:00   73    25834403      m          linfócitos %
# 4       2021-07-24 00:19:00   17    25848842      f      plaquetas sangue
# ...                     ...  ...         ...    ...                   ...
# 134477  2021-12-03 09:31:00   25    24766171      m      plaquetas sangue
# 134478  2021-12-03 09:31:00   25    24766171      m  neutrófilos absoluto
# 134479  2021-12-03 09:31:00   25    24766171      m   linfócitos absoluto
# 134480  2021-12-03 09:31:00   25    24766171      m         neutrófilos %
# 134481  2021-12-03 09:31:00   25    24766171      m          linfócitos %
#
#         quantity
# 0         2.9153
# 1         1.8109
# 2        29.3000
# 3        18.2000
# 4       321.0000
# ...          ...
# 134477   58.0000
# 134478    1.2600
# 134479    1.3104
# 134480   45.0000
# 134481   46.8000
#
# [134482 rows x 6 columns]

# %%
df1["plaquetas_sangue"].unique()
# Out:
# <StringArray>
# [           'plaquetas_sangue',        'neutrófilos_absoluto',
#          'linfócitos_absoluto',               'neutrófilos_%',
#                 'linfócitos_%',           'leucócitos_totais',
#                         'mchc',        'eosinófilos_absoluto',
#                 'luc_absoluto',   'neutrófilos_segmentados_%',
#                        'luc_%', 'linfocitos_atipicos_total_%',
#         'plasmócitos_absoluto',                'plasmócitos%',
#               'observação_wbc',              'observação_rbc',
#               'observação_plt']
# Length: 17, dtype: str

# %%
df1["plaquetas_sangue"].value_counts()
# Out:
# plaquetas_sangue
# neutrófilos_absoluto           12105
# linfócitos_absoluto            12105
# plaquetas_sangue               12104
# linfócitos_%                   12104
# neutrófilos_%                  11293
# leucócitos_totais                811
# mchc                             811
# eosinófilos_absoluto             811
# luc_absoluto                     811
# neutrófilos_segmentados_%        811
# luc_%                            811
# linfocitos_atipicos_total_%      811
# plasmócitos_absoluto             811
# plasmócitos%                     811
# observação_wbc                   811
# observação_rbc                   811
# observação_plt                   811
# Name: count, dtype: int64

# %%
df1.groupby("plaquetas_sangue")["quantity"].apply(lambda x: x.isnull().mean())
# Out:
# plaquetas_sangue
# eosinófilos_absoluto           0.001233
# leucócitos_totais              1.000000
# linfocitos_atipicos_total_%    0.998767
# linfócitos_%                   0.000826
# linfócitos_absoluto            0.000743
# luc_%                          1.000000
# luc_absoluto                   1.000000
# mchc                           0.000000
# neutrófilos_%                  0.000797
# neutrófilos_absoluto           0.000743
# neutrófilos_segmentados_%      0.001233
# observação_plt                 1.000000
# observação_rbc                 1.000000
# observação_wbc                 1.000000
# plaquetas_sangue               0.000083
# plasmócitos%                   0.998767
# plasmócitos_absoluto           0.998767
# Name: quantity, dtype: float64

# %%
df1['quantity'] = (
    df1['quantity']
    .astype(str)
    .str.replace(',', '.', regex=False)
)

df1['quantity'] = pd.to_numeric(df1['quantity'])

for exame in df1["plaquetas_sangue"].unique():
    
    subset = df1[df1["plaquetas_sangue"] == exame]
    
    plt.hist(subset["quantity"], bins=40)
    plt.title(exame)
    plt.show()
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7104: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7105: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 13
#       9 for exame in df1["plaquetas_sangue"].unique():
#      11     subset = df1[df1["plaquetas_sangue"] == exame]
# ---> 13     plt.hist(subset["quantity"], bins=40)
#      14     plt.title(exame)
#      15     plt.show()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/pyplot.py:3478, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3453 @_copy_docstring_and_deprecators(Axes.hist)
#    3454 def hist(
#    3455     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3476     BarContainer | Polygon | list[BarContainer | Polygon],
#    3477 ]:
# -> 3478     return gca().hist(
#    3479         x,
#    3480         bins=bins,
#    3481         range=range,
#    3482         density=density,
#    3483         weights=weights,
#    3484         cumulative=cumulative,
#    3485         bottom=bottom,
#    3486         histtype=histtype,
#    3487         align=align,
#    3488         orientation=orientation,
#    3489         rwidth=rwidth,
#    3490         log=log,
#    3491         color=color,
#    3492         label=label,
#    3493         stacked=stacked,
#    3494         **({"data": data} if data is not None else {}),
#    3495         **kwargs,
#    3496     )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/axes/_axes.py:7132, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7128 # Loop through datasets
#    7129 for i in range(nx):
#    7130     # this will automatically overwrite bins,
#    7131     # so that each histogram uses the same bins
# -> 7132     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7133     tops.append(m)
#    7134 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:792, in histogram(a, bins, range, density, weights)
#     687 r"""
#     688 Compute the histogram of a dataset.
#     689
#    (...)    788
#     789 """
#     790 a, weights = _ravel_and_check_weights(a, weights)
# --> 792 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     794 # Histogram is an integer or a float array depending on the weights.
#     795 if weights is None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:425, in _get_bin_edges(a, bins, range, weights)
#     422     if n_equal_bins < 1:
#     423         raise ValueError('`bins` must be positive, when an integer')
# --> 425     first_edge, last_edge = _get_outer_edges(a, range)
#     427 elif np.ndim(bins) == 1:
#     428     bin_edges = np.asarray(bins)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:317, in _get_outer_edges(a, range)
#     315     first_edge, last_edge = a.min(), a.max()
#     316     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 317         raise ValueError(
#     318             f"autodetected range of [{first_edge}, {last_edge}] is not finite")
#     320 # expand empty range to avoid divide by zero
#     321 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
df1.groupby("plaquetas_sangue")["quantity"].apply(lambda x: x.isnull().sum())
# Out:
# plaquetas_sangue
# eosinófilos_absoluto             1
# leucócitos_totais              811
# linfocitos_atipicos_total_%    810
# linfócitos_%                    10
# linfócitos_absoluto              9
# luc_%                          811
# luc_absoluto                   811
# mchc                             0
# neutrófilos_%                    9
# neutrófilos_absoluto             9
# neutrófilos_segmentados_%        1
# observação_plt                 811
# observação_rbc                 811
# observação_wbc                 811
# plaquetas_sangue                 1
# plasmócitos%                   810
# plasmócitos_absoluto           810
# Name: quantity, dtype: int64

# %%
df1[df1['plaquetas_sangue'] == 'leucócitos_totais']
# Out:
#                  date_time  age  patient_id gender   plaquetas_sangue  \
# 49     2021-10-24_05:31:00   54    25595648      f  leucócitos_totais
# 50     2021-10-24_05:31:00   61    25149430      m  leucócitos_totais
# 51     2021-10-24_05:31:00   59    12805068      m  leucócitos_totais
# 52     2021-10-24_05:31:00   58    24932063      f  leucócitos_totais
# 53     2021-10-24_05:31:00   63    24909035      f  leucócitos_totais
# ...                    ...  ...         ...    ...                ...
# 67273  2021-12-09_05:50:00   32    25920281      m  leucócitos_totais
# 67274  2021-12-09_05:50:00   54    25595648      f  leucócitos_totais
# 67275  2021-12-09_05:50:00   54    25823239      m  leucócitos_totais
# 67391  2021-12-09_07:30:00   61    25843342      f  leucócitos_totais
# 67392  2021-12-09_07:30:00   54    12284312      m  leucócitos_totais
#
#        quantity
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# ...         ...
# 67273       NaN
# 67274       NaN
# 67275       NaN
# 67391       NaN
# 67392       NaN
#
# [811 rows x 6 columns]

# %%
missing_rate = df1.groupby("plaquetas_sangue")["quantity"].apply(lambda x: x.isnull().mean())

valid_exams = missing_rate[missing_rate < 0.5].index

df1 = df1[df1["plaquetas_sangue"].isin(valid_exams)]

# %%
df1 = df1.dropna(subset=["quantity"])

# %%
df1['quantity'].isnull().sum()
# Out:
# np.int64(0)

# %%
df1
# Out:
#                  date_time  age  patient_id gender      plaquetas_sangue  \
# 0      2021-10-24_00:33:00   70    16084789      m      plaquetas_sangue
# 1      2021-10-24_00:33:00   62    25926519      f      plaquetas_sangue
# 2      2021-10-24_00:33:00   49    20209887      m      plaquetas_sangue
# 3      2021-10-24_00:33:00   50    25722538      m      plaquetas_sangue
# 4      2021-10-24_00:33:00   19    20850235      f  neutrófilos_absoluto
# ...                    ...  ...         ...    ...                   ...
# 69438  2021-12-10_05:44:00   52    14708160      f      plaquetas_sangue
# 69439  2021-12-10_05:44:00   52    14708160      f  neutrófilos_absoluto
# 69440  2021-12-10_05:44:00   52    14708160      f   linfócitos_absoluto
# 69441  2021-12-10_05:44:00   52    14708160      f         neutrófilos_%
# 69442  2021-12-10_05:44:00   52    14708160      f          linfócitos_%
#
#        quantity
# 0      239.0000
# 1      166.0000
# 2      201.0000
# 3      319.0000
# 4        9.9006
# ...         ...
# 69438  172.0000
# 69439   10.4661
# 69440    0.3609
# 69441   87.0000
# 69442    3.0000
#
# [62104 rows x 6 columns]

# %%
missing_rate_df2 = df2.groupby("plaquetas_sangue")["quantity"].apply(lambda x: x.isnull().mean())

valid_exams = missing_rate_df2[missing_rate_df2 < 0.5].index

df2 = df2[df2["plaquetas_sangue"].isin(valid_exams)]

# %%
df2 = df2.dropna(subset=["quantity"])

# %%
df2
# Out:
#                   date_time  age  patient_id gender      plaquetas_sangue  \
# 0       2019-04-07_13:36:00   38    22536285      m  neutrófilos_absoluto
# 1       2019-04-07_13:36:00   38    22536285      m   linfócitos_absoluto
# 2       2019-04-07_13:36:00   38    22536285      m         neutrófilos_%
# 3       2019-04-07_13:36:00   38    22536285      m          linfócitos_%
# 4       2019-10-12_12:53:00    7    25368842      m      plaquetas_sangue
# ...                     ...  ...         ...    ...                   ...
# 152918  2020-11-19_10:09:00   43    24249245      m      plaquetas_sangue
# 152919  2020-11-19_10:09:00   43    24249245      m  neutrófilos_absoluto
# 152920  2020-11-19_10:09:00   43    24249245      m   linfócitos_absoluto
# 152921  2020-11-19_10:09:00   43    24249245      m         neutrófilos_%
# 152922  2020-11-19_10:09:00   43    24249245      m          linfócitos_%
#
#         quantity
# 0         5.8476
# 1         3.1896
# 2        44.0000
# 3        24.0000
# 4       268.0000
# ...          ...
# 152918  234.0000
# 152919    3.8994
# 152920    1.8293
# 152921   59.9000
# 152922   28.1000
#
# [142764 rows x 6 columns]

# %%
missing_rate_df3 = df3.groupby("plaquetas_sangue")["quantity"].apply(lambda x: x.isnull().mean())

valid_exams = missing_rate_df3[missing_rate_df3 < 0.5].index

df3 = df3[df3["plaquetas_sangue"].isin(valid_exams)]

# %%
df3 = df3.dropna(subset=["quantity"])

# %%
df3.isnull().sum()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# date_time           0
# age                 0
# patient_id          0
# gender              0
# plaquetas_sangue    0
# quantity            0
# dtype: int64

# %%
df1["plaquetas_sangue"].value_counts()
# Out:
# plaquetas_sangue
# plaquetas_sangue             12103
# neutrófilos_absoluto         12096
# linfócitos_absoluto          12096
# linfócitos_%                 12094
# neutrófilos_%                11284
# mchc                           811
# eosinófilos_absoluto           810
# neutrófilos_segmentados_%      810
# Name: count, dtype: int64

# %%
df2["plaquetas_sangue"].value_counts()
# Out:
# plaquetas_sangue
# plaquetas_sangue             27970
# neutrófilos_absoluto         27266
# linfócitos_absoluto          27265
# linfócitos_%                 27163
# neutrófilos_%                25974
# leucócitos_totais             1188
# mchc                          1188
# eosinófilos_absoluto          1188
# luc_absoluto                  1188
# neutrófilos_segmentados_%     1187
# luc_%                         1187
# Name: count, dtype: int64

# %%
df3["plaquetas_sangue"].value_counts()
# Out:
# plaquetas_sangue
# plaquetas sangue             23985
# neutrófilos absoluto         23932
# linfócitos absoluto          23932
# linfócitos %                 23930
# neutrófilos %                22611
# eosinófilos absoluto          1319
# neutrófilos segmentados %     1319
# mchc                          1318
# Name: count, dtype: int64

# %%
for exame in df1["plaquetas_sangue"].unique():

    subset = df1[df1["plaquetas_sangue"] == exame]["quantity"]

    print(exame)
    print(subset.describe())

    plt.hist(subset, bins=40)
    plt.show()
# Out:
# plaquetas_sangue
# count    12103.000000
# mean       235.440800
# std        119.086829
# min          1.000000
# 25%        167.500000
# 50%        227.000000
# 75%        292.000000
# max       2708.000000
# Name: quantity, dtype: float64
# neutrófilos_absoluto
# count    12096.000000
# mean         5.342662
# std          4.486107
# min          0.000000
# 25%          2.981325
# 50%          4.315550
# 75%          6.447925
# max        187.682000
# Name: quantity, dtype: float64
# linfócitos_absoluto
# count    12096.000000
# mean         2.029342
# std          7.258043
# min          0.000000
# 25%          1.028075
# 50%          1.637550
# 75%          2.288000
# max        246.984000
# Name: quantity, dtype: float64
# neutrófilos_%
# count    11284.000000
# mean        62.625514
# std         14.290332
# min          0.000000
# 25%         53.800000
# 50%         62.800000
# 75%         72.500000
# max         99.000000
# Name: quantity, dtype: float64
# linfócitos_%
# count    12094.000000
# mean        24.954506
# std         14.312969
# min          0.000000
# 25%         14.500000
# 50%         23.950000
# 75%         33.000000
# max        100.000000
# Name: quantity, dtype: float64
# mchc
# count    811.000000
# mean      32.977928
# std        1.741432
# min       26.000000
# 25%       32.000000
# 50%       33.100000
# 75%       34.100000
# max       37.600000
# Name: quantity, dtype: float64
# eosinófilos_absoluto
# count    810.000000
# mean       0.170523
# std        1.038535
# min        0.000000
# 25%        0.000000
# 50%        0.009100
# 75%        0.065750
# max       13.027800
# Name: quantity, dtype: float64
# neutrófilos_segmentados_%
# count    810.000000
# mean      53.004321
# std       28.169341
# min        0.000000
# 25%       33.300000
# 50%       58.300000
# 75%       73.600000
# max      100.000000
# Name: quantity, dtype: float64

# %%
for exame in df2["plaquetas_sangue"].unique():

    subset = df2[df2["plaquetas_sangue"] == exame]["quantity"]

    print(exame)
    print(subset.describe())

    plt.hist(subset, bins=40)
    plt.show()
# Out:
# neutrófilos_absoluto
# count    27266.000000
# mean         5.328352
# std          4.270207
# min          0.000000
# 25%          3.050000
# 50%          4.390000
# 75%          6.399100
# max        173.300000
# Name: quantity, dtype: float64
# linfócitos_absoluto
# count    27265.000000
# mean         1.910988
# std          1.755935
# min          0.000000
# 25%          1.110000
# 50%          1.740000
# 75%          2.380000
# max        101.700000
# Name: quantity, dtype: float64
# neutrófilos_%
# count    25974.000000
# mean        63.680457
# std         14.114929
# min          1.000000
# 25%         55.000000
# 50%         63.800000
# 75%         73.200000
# max         98.400000
# Name: quantity, dtype: float64
# linfócitos_%
# count    27163.000000
# mean        26.183003
# std         13.503904
# min          0.000000
# 25%         16.600000
# 50%         25.700000
# 75%         34.300000
# max         96.600000
# Name: quantity, dtype: float64
# plaquetas_sangue
# count    27970.000000
# mean       250.143940
# std        126.722562
# min          1.000000
# 25%        179.000000
# 50%        237.000000
# 75%        303.000000
# max       2626.000000
# Name: quantity, dtype: float64
# leucócitos_totais
# count    1188.000000
# mean        7.228350
# std        17.730339
# min         0.000000
# 25%         0.797500
# 50%         3.615000
# 75%         7.465000
# max       257.400000
# Name: quantity, dtype: float64
# mchc
# count    1188.000000
# mean       34.313805
# std         1.350832
# min        28.900000
# 25%        33.400000
# 50%        34.300000
# 75%        35.200000
# max        41.800000
# Name: quantity, dtype: float64
# eosinófilos_absoluto
# count    1188.000000
# mean        0.211153
# std         1.412292
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.070000
# max        30.900000
# Name: quantity, dtype: float64
# luc_absoluto
# count    1188.000000
# mean        0.527374
# std         4.794664
# min         0.000000
# 25%         0.020000
# 50%         0.060000
# 75%         0.170000
# max        95.520000
# Name: quantity, dtype: float64
# neutrófilos_segmentados_%
# count    1187.000000
# mean       60.144061
# std        26.215507
# min         0.800000
# 25%        39.650000
# 50%        64.200000
# 75%        83.800000
# max        98.600000
# Name: quantity, dtype: float64
# luc_%
# count    1187.000000
# mean        4.293682
# std         5.606325
# min         0.000000
# 25%         1.000000
# 50%         2.500000
# 75%         5.500000
# max        69.500000
# Name: quantity, dtype: float64

# %%
for exame in df3["plaquetas_sangue"].unique():

    subset = df3[df3["plaquetas_sangue"] == exame]["quantity"]

    print(exame)
    print(subset.describe())

    plt.hist(subset, bins=40)
    plt.show()
# Out:
# neutrófilos absoluto
# count    23932.000000
# mean         5.467928
# std          4.471684
# min          0.000000
# 25%          3.067550
# 50%          4.419100
# 75%          6.561075
# max        109.726000
# Name: quantity, dtype: float64
# linfócitos absoluto
# count    23932.000000
# mean         2.015754
# std          6.902551
# min          0.000000
# 25%          1.058575
# 50%          1.661100
# 75%          2.321400
# max        369.244800
# Name: quantity, dtype: float64
# neutrófilos %
# count    22611.000000
# mean        62.618571
# std         14.491293
# min          0.000000
# 25%         53.600000
# 50%         62.800000
# 75%         72.600000
# max        100.000000
# Name: quantity, dtype: float64
# linfócitos %
# count    23930.000000
# mean        24.757058
# std         13.951513
# min          0.000000
# 25%         14.500000
# 50%         23.900000
# 75%         32.900000
# max        100.000000
# Name: quantity, dtype: float64
# plaquetas sangue
# count    23985.000000
# mean       240.664976
# std        114.246047
# min          1.000000
# 25%        174.000000
# 50%        232.000000
# 75%        296.000000
# max       1410.000000
# Name: quantity, dtype: float64
# mchc
# count    1318.000000
# mean       33.041199
# std         1.862978
# min        25.400000
# 25%        32.100000
# 50%        33.200000
# 75%        34.200000
# max        45.300000
# Name: quantity, dtype: float64
# eosinófilos absoluto
# count    1319.000000
# mean        0.109341
# std         0.285785
# min         0.000000
# 25%         0.000000
# 50%         0.016500
# 75%         0.121900
# max         3.524600
